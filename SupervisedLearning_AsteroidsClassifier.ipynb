# %% [markdown]
# <a href="https://colab.research.google.com/github/Juskocode/SupervisedLearning-AsteroidsClassifier/blob/main/SupervisedLearning_AsteroidsClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown

# Install p7zip for extracting .7z files (if needed)
# !sudo apt-get install p7zip-full
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %% [markdown]
# # Libraries

# %%
import gdown
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
import warnings
warnings.filterwarnings('ignore')

from collections import Counter

from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import  confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import validation_curve


from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# # downloading dataset from kaggle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lovishbansal123/nasa-asteroids-classification")

# %% [markdown]
# # importing dataset

# %%
nasa_df = pd.read_csv(f"{path}/nasa.csv")
# Ensure all columns are displayed
pd.set_option('display.max_columns', None)

nasa_df.head()
# Out:
#    Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0           3703080  3703080                21.6            0.127220
# 1           3723955  3723955                21.3            0.146068
# 2           2446862  2446862                20.3            0.231502
# 3           3092506  3092506                27.4            0.008801
# 4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219879         284.472297
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219879         284.472297
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  \
# 0               0.079051               0.176763            417.388066
# ...

# %%
nasa_df.shape
# Out:
# (4687, 40)

# %% [markdown]
# # DataSet describe and modularity

# %%
nasa_df.describe()
# Out:
#        Neo Reference ID          Name  Absolute Magnitude  Est Dia in KM(min)  \
# count      4.687000e+03  4.687000e+03         4687.000000         4687.000000
# mean       3.272298e+06  3.272298e+06           22.267865            0.204604
# std        5.486011e+05  5.486011e+05            2.890972            0.369573
# min        2.000433e+06  2.000433e+06           11.160000            0.001011
# 25%        3.097594e+06  3.097594e+06           20.100000            0.033462
# 50%        3.514799e+06  3.514799e+06           21.900000            0.110804
# 75%        3.690060e+06  3.690060e+06           24.500000            0.253837
# max        3.781897e+06  3.781897e+06           32.100000           15.579552
#
#        Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# count         4687.000000        4687.000000        4687.000000
# mean             0.457509         204.604203         457.508906
# std              0.826391         369.573402         826.391249
# ...

# %%
nasa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Neo Reference ID              4687 non-null   int64
#  1   Name                          4687 non-null   int64
#  2   Absolute Magnitude            4687 non-null   float64
#  3   Est Dia in KM(min)            4687 non-null   float64
#  4   Est Dia in KM(max)            4687 non-null   float64
#  5   Est Dia in M(min)             4687 non-null   float64
#  6   Est Dia in M(max)             4687 non-null   float64
#  7   Est Dia in Miles(min)         4687 non-null   float64
#  8   Est Dia in Miles(max)         4687 non-null   float64
#  9   Est Dia in Feet(min)          4687 non-null   float64
#  10  Est Dia in Feet(max)          4687 non-null   float64
#  11  Close Approach Date           4687 non-null   object
# ...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### Droping columns which are not useful for the classification process

# %%
nasa_df = nasa_df.drop(['Neo Reference ID', 'Name', 'Orbit ID', 'Close Approach Date',
                        'Epoch Date Close Approach', 'Orbit Determination Date'] , axis = 1)
nasa_df.head()
# Out:
#    Absolute Magnitude  Est Dia in KM(min)  Est Dia in KM(max)  \
# 0                21.6            0.127220            0.284472
# 1                21.3            0.146068            0.326618
# 2                20.3            0.231502            0.517654
# 3                27.4            0.008801            0.019681
# 4                21.6            0.127220            0.284472
#
#    Est Dia in M(min)  Est Dia in M(max)  Est Dia in Miles(min)  \
# 0         127.219879         284.472297               0.079051
# 1         146.067964         326.617897               0.090762
# 2         231.502122         517.654482               0.143849
# 3           8.801465          19.680675               0.005469
# 4         127.219879         284.472297               0.079051
#
#    Est Dia in Miles(max)  Est Dia in Feet(min)  Est Dia in Feet(max)  \
# 0               0.176763            417.388066            933.308089
# 1               0.202951            479.225620           1071.581063
# ...

# %%
nasa_df.shape
# Out:
# (4687, 34)

# %% [markdown]
# #### Check for unique values on data set

# %%
unique_values = []
for col in nasa_df.columns:
    if len(set(nasa_df[col].unique())) == 1:
      print(f"{col}")
      unique_values.append(col)
# Out:
# Orbiting Body
# Equinox

# %% [markdown]
# ##### drop unique values

# %%
nasa_df = nasa_df.drop([col for col in unique_values], axis = 1)
nasa_df.head()
# Out:
#    Absolute Magnitude  Est Dia in KM(min)  Est Dia in KM(max)  \
# 0                21.6            0.127220            0.284472
# 1                21.3            0.146068            0.326618
# 2                20.3            0.231502            0.517654
# 3                27.4            0.008801            0.019681
# 4                21.6            0.127220            0.284472
#
#    Est Dia in M(min)  Est Dia in M(max)  Est Dia in Miles(min)  \
# 0         127.219879         284.472297               0.079051
# 1         146.067964         326.617897               0.090762
# 2         231.502122         517.654482               0.143849
# 3           8.801465          19.680675               0.005469
# 4         127.219879         284.472297               0.079051
#
#    Est Dia in Miles(max)  Est Dia in Feet(min)  Est Dia in Feet(max)  \
# 0               0.176763            417.388066            933.308089
# 1               0.202951            479.225620           1071.581063
# ...

# %% [markdown]
# #### Unit Values stadartization
# Just by analyse the head of the data set, we can see that there are a couple o columns with the same, but in different units, we can prove they are the same, but just in different units by apllying pearson's correlation.

# %%
plt.figure(figsize = (20,20))
# subsetdataFrame of only unitary columns
sub_df = nasa_df.iloc[:, :16]

sns.heatmap(sub_df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# as we can see the correlation between those columns is too perfect, thus we can conclude that they are the same value just in a diferent unit, so we drop them

# %%
nasa_df = nasa_df.drop(['Est Dia in KM(max)', 'Est Dia in M(min)', 'Est Dia in M(max)', 'Est Dia in Miles(min)'
             ,'Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)',
             'Relative Velocity km per hr', 'Miles per hour', 'Miss Dist.(lunar)',
             'Miss Dist.(kilometers)', 'Miss Dist.(miles)'], axis = 1)
nasa_df.head()
# Out:
#    Absolute Magnitude  Est Dia in KM(min)  Relative Velocity km per sec  \
# 0                21.6            0.127220                      6.115834
# 1                21.3            0.146068                     18.113985
# 2                20.3            0.231502                      7.590711
# 3                27.4            0.008801                     11.173874
# 4                21.6            0.127220                      9.840831
#
#    Miss Dist.(Astronomical)  Orbit Uncertainity  Minimum Orbit Intersection  \
# 0                  0.419483                   5                    0.025282
# 1                  0.383014                   3                    0.186935
# 2                  0.050956                   0                    0.043058
# 3                  0.285322                   6                    0.005512
# 4                  0.407832                   1                    0.034798
#
#    Jupiter Tisserand Invariant  Epoch Osculation  Eccentricity  \
# ...

# %%
nasa_df.shape
# Out:
# (4687, 20)

# %% [markdown]
# now the dataframe is reduce to only 21 features, much more flexibel to work and to optimize the results

# %% [markdown]
# #### Categorial values

# %%
categories = ["Orbit Uncertainity", "Hazardous"]
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 7))
for i, j in enumerate(categories):
    counts = nasa_df[j].value_counts()
    counts.plot(kind="bar", ax=axes[i])
    if len(counts) <= 10:
        for container in axes[i].containers:
            axes[i].bar_label(container)
    else:
        axes[i].set_xticklabels(())
plt.tight_layout()
plt.show()

# %% [markdown]
# #### numerical values

# %%
numericals = []
for i in nasa_df.columns:
    if i not in categories+["Close Approach Date", "Orbiting Body", "Orbit Determination Date", "Equinox"]:
        numericals += [i]

# %% [markdown]
# #### Numerical densities for Hazardous vs non-Hazardous

# %%
index = 0
total_cols = nasa_df.shape[1]  # Total number of columns in nasa_df

for i in range(5):
    cols = 6
    if i == 4:
        cols -= 1  # Adjust columns for the last row

    # Ensure we don't create extra plots beyond the number of columns
    cols = min(cols, total_cols - index)
    if cols <= 0:  # Break if no columns are left to plot
        break

    fig, axes = plt.subplots(nrows=1, ncols=cols, figsize=(20, 5))
    for j in range(cols):
        sns.kdeplot(nasa_df, x=nasa_df.columns[index], hue=categories[-1], ax=axes[j])
        index += 1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Correlations map after dataCleaning

# %%
plt.figure(figsize = (20,20))
sns.heatmap(nasa_df.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
nasa_df.drop(nasa_df.columns[-2], axis=1)
nasa_df.head()
# Out:
#    Absolute Magnitude  Est Dia in KM(min)  Relative Velocity km per sec  \
# 0                21.6            0.127220                      6.115834
# 1                21.3            0.146068                     18.113985
# 2                20.3            0.231502                      7.590711
# 3                27.4            0.008801                     11.173874
# 4                21.6            0.127220                      9.840831
#
#    Miss Dist.(Astronomical)  Orbit Uncertainity  Minimum Orbit Intersection  \
# 0                  0.419483                   5                    0.025282
# 1                  0.383014                   3                    0.186935
# 2                  0.050956                   0                    0.043058
# 3                  0.285322                   6                    0.005512
# 4                  0.407832                   1                    0.034798
#
#    Jupiter Tisserand Invariant  Epoch Osculation  Eccentricity  \
# ...

# %%
nasa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Absolute Magnitude            4687 non-null   float64
#  1   Est Dia in KM(min)            4687 non-null   float64
#  2   Relative Velocity km per sec  4687 non-null   float64
#  3   Miss Dist.(Astronomical)      4687 non-null   float64
#  4   Orbit Uncertainity            4687 non-null   int64
#  5   Minimum Orbit Intersection    4687 non-null   float64
#  6   Jupiter Tisserand Invariant   4687 non-null   float64
#  7   Epoch Osculation              4687 non-null   float64
#  8   Eccentricity                  4687 non-null   float64
#  9   Semi Major Axis               4687 non-null   float64
#  10  Inclination                   4687 non-null   float64
#  11  Asc Node Longitude            4687 non-null   float64
# ...

# %%
nasa_df.describe()
# Out:
#        Absolute Magnitude  Est Dia in KM(min)  Relative Velocity km per sec  \
# count         4687.000000         4687.000000                   4687.000000
# mean            22.267865            0.204604                     13.970811
# std              2.890972            0.369573                      7.293223
# min             11.160000            0.001011                      0.335504
# 25%             20.100000            0.033462                      8.432865
# 50%             21.900000            0.110804                     12.917889
# 75%             24.500000            0.253837                     18.077649
# max             32.100000           15.579552                     44.633747
#
#        Miss Dist.(Astronomical)  Orbit Uncertainity  \
# count               4687.000000         4687.000000
# mean                   0.256778            3.516962
# std                    0.145798            3.078307
# min                    0.000178            0.000000
# ...

# %% [markdown]
# #### Encoding Hazardous and non Hazardous asteroids

# %%
le = LabelEncoder()
nasa_df["Hazardous"] = le.fit_transform(nasa_df["Hazardous"])

# %%
nasa_df.head()
# Out:
#    Absolute Magnitude  Est Dia in KM(min)  Relative Velocity km per sec  \
# 0                21.6            0.127220                      6.115834
# 1                21.3            0.146068                     18.113985
# 2                20.3            0.231502                      7.590711
# 3                27.4            0.008801                     11.173874
# 4                21.6            0.127220                      9.840831
#
#    Miss Dist.(Astronomical)  Orbit Uncertainity  Minimum Orbit Intersection  \
# 0                  0.419483                   5                    0.025282
# 1                  0.383014                   3                    0.186935
# 2                  0.050956                   0                    0.043058
# 3                  0.285322                   6                    0.005512
# 4                  0.407832                   1                    0.034798
#
#    Jupiter Tisserand Invariant  Epoch Osculation  Eccentricity  \
# ...

# %% [markdown]
# Scaling features

# %%
data = nasa_df.values
x, y = data[:, :-1], data[:, -1]

scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 300, test_size=0.2)

# %% [markdown]
# #### Applying SMOTE to deal with bias and class imbalances

# %%
print("Values before smote", Counter(y_train))
smote = SMOTE()
x_train, y_train = smote.fit_resample(x_train, y_train)
print("After: ", Counter(y_train.tolist()))
# Out:
# Values before smote Counter({0.0: 3141, 1.0: 608})
# After:  Counter({0.0: 3141, 1.0: 3141})

# %% [markdown]
# Feature analyses - which feature affects hazardous asteroids vs non-hazardous

# %%
forest = RandomForestClassifier()
forest.fit(x_train, y_train)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)

forest_importances = pd.Series(importances, index=numericals+categories[:-1])

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Set up training

# %%
def training(model, name, axes):

    model.fit(x_train, y_train)
    pred = model.predict(x_test)

    score = accuracy_score(y_test, pred)
    report = classification_report(y_test, pred)

    cm = confusion_matrix(y_test, pred)
    sns.heatmap(cm, annot=True, ax=axes)
    axes.set_title("{}: {}%".format(name, round(score*100, 2)))

    return score*100, report

# %%
rfc = RandomForestClassifier()
abc = AdaBoostClassifier()
gbc = GradientBoostingClassifier()
etc = ExtraTreesClassifier()
lgr = LogisticRegression(random_state=64)
svc = SVC()
dtc = DecisionTreeClassifier()
xgb = XGBClassifier()

models = [rfc, abc, gbc, etc, lgr, svc, dtc, xgb]
names = ["Random Forest", "Ada Boost", "Gradient Boosting",
        "Extra Trees", "Logistic Regression", "Support Vectors",
        "Decision Tree", "XGBoost"]

# %% [markdown]
# ## Training and evaluation

# %%
scores = []
reports = dict()
index = 0
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 7))
for i in range(2):
    for j in range(4):
        score, report = training(models[index], names[index], axes[i][j])
        scores += [score]
        reports[names[index]] = report
        index += 1
plt.tight_layout()
plt.show()

# %%
dt = pd.DataFrame({"scores": scores}, index=names)
dt = dt.sort_values("scores", ascending=False)
dt["scores"] = round(dt["scores"], 2)
fig, axes = plt.subplots()
sns.barplot(x=dt.index, y=dt.iloc[:, 0], ax=axes)
for container in axes.containers:
    axes.bar_label(container)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
plt.show()

# %%
for i in dt.index:
    print("*"*55)
    print(i)
    print(reports[i])
    print("\n\n")
# Out:
# *******************************************************
# Random Forest
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       791
#          1.0       0.98      0.99      0.99       147
#
#     accuracy                           1.00       938
#    macro avg       0.99      0.99      0.99       938
# weighted avg       1.00      1.00      1.00       938
#
#
#
#
# *******************************************************
# Decision Tree
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       791
#          1.0       0.98      0.99      0.99       147
#
#     accuracy                           1.00       938
#    macro avg       0.99      0.99      0.99       938
# weighted avg       1.00      1.00      1.00       938
#
#
#
#
# *******************************************************
# Ada Boost
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ## Logistic Regression Hyperparameter Tuning with Validation Curves
#
# This guide explains how to perform hyperparameter tuning for Logistic Regression using **validation curves**. The example focuses on the `C` parameter, which controls the strength of regularization in the Logistic Regression model.
#
# ---
#
# ###### What is a Validation Curve?
#
# A **validation curve** helps assess a model's performance over a range of hyperparameter values. By comparing training and cross-validation scores, we can identify:
#
# 1. Overfitting: When the model performs well on training data but poorly on validation data.
# 2. Underfitting: When the model performs poorly on both training and validation data.
#
# ---
#
# ##### Logistic Regression Hyperparameter `C`
#
# - **Definition**: The `C` parameter is the inverse of regularization strength. Smaller values indicate stronger regularization, while larger values relax the regularization.
# - **Range**: In this example, we test values from `0.0001` to `10000` on a logarithmic scale.

# %%
# Define the range of values for the 'C' parameter
param_range = np.logspace(-3, 4, 50)  # Test C values from 0.0001 to 10000

# Create a Logistic Regression classifier
classifier = LogisticRegression(max_iter=25, solver='liblinear')  # Adjust solver for L1 regularization if needed

# Calculate validation scores for different values of C
train_scores, test_scores = validation_curve(
    estimator=classifier,
    X=x_train,
    y=y_train,
    param_name='C',
    param_range=param_range,
    cv=5  # Number of cross-validation folds
)

# Calculate the mean and standard deviation of training and test scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Find the position where the cross-validation score is highest
best_index = np.argmax(test_mean)

# Find the C value corresponding to the found position
C_best_param = param_range[best_index]

# Calculate the indices of points adjacent to the best point
left_index = max(0, best_index - 1)
right_index = min(len(param_range) - 1, best_index + 1)

# Plot the validation curve
plt.plot(param_range, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(param_range, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(param_range, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Cross-Validation Score')
plt.fill_between(param_range, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

# Plot markers at points corresponding to the best, left, and right positions
plt.scatter([param_range[best_index], param_range[left_index], param_range[right_index]],
            [test_mean[best_index], test_mean[left_index], test_mean[right_index]],
            color='red', marker='o', s=150, label='Best Position')

# Update plot settings
plt.xscale('log')  # Log scale for the x-axis since C values are logarithmic
plt.title('Validation Curve for Logistic Regression')
plt.xlabel('C (Inverse Regularization Strength)')
plt.ylabel('Score')
plt.legend(loc='lower right')
plt.grid()
plt.xticks(param_range, rotation=45)

# Show the plot
plt.show()

print(f"The best C value is: {C_best_param}")
# Out:
# The best C value is: 1930.6977288832495

# %% [markdown]
# ### Conclusion: Optimal \( C \) Value for Logistic Regression
#
# After tuning the hyperparameter \( C \) for Logistic Regression, the optimal value was determined to be **1.93*10^3**. This value represents an extremely **low regularization strength** (since \( C \) is the inverse of regularization), which has several implications:
#
# ---
#
# ### Implications of \( C = 1.93*10^3 \)
#
# #### 1. Model Complexity
# - A very high \( C \) value significantly reduces the regularization effect, allowing the model to fit the training data almost perfectly.
# - While this can capture highly complex patterns in the data, it risks learning noise or insignificant variations.
#
# #### 2. Impact on Overfitting
# - With \( C = **1.93*10^3** \), the model is highly flexible and fits the training data very closely. This can increase the risk of **overfitting** if the dataset contains noise or irrelevant features.
# - However, the validation scores from the cross-validation process suggest that overfitting is not a major issue here. The training and validation scores are still aligned, indicating good generalization.
#
# #### 3. Impact on Underfitting
# - A very low regularization effect minimizes the risk of **underfitting**, as the model is not constrained from capturing complex patterns.
# - This is advantageous for datasets with intricate relationships or large feature sets.
#
# #### 4. Interpretability
# - Logistic Regression models with such a high \( C \) value may lose interpretability. The model coefficients can become excessively large, making it harder to infer meaningful relationships between features and the target variable.
#
# ---
#
# #### Why \( C = **1.93*10^3** \) is Ideal in This Case
#
# - **Balanced Performance**: Despite the high \( C \), the validation curve shows that \( C = **1.93*10^3** \) achieves the best balance between training and validation performance, avoiding significant overfitting or underfitting.
# - **Dataset Characteristics**: The dataset likely has complex patterns or relationships that benefit from reduced regularization, allowing the model to better fit the data.
#
# ---
#
# #### Practical Takeaways
#
# 1. The chosen \( C = **1.93*10^3** \) ensures the model fits the data extremely well while maintaining good generalization to unseen data.
# 2. To further enhance the model:
#    - Monitor for overfitting using independent test data, as high \( C \) values can sometimes cause overfitting in noisier datasets.
#    - Consider dimensionality reduction or feature selection if the dataset is large, to improve interpretability and robustness.
#    - Experiment with alternative penalties such as `l1` or `elasticnet` to better control model complexity.
# 3. Always validate the model’s performance on a separate test set to confirm its ability to generalize.
#
# ---
#
# This conclusion highlights the trade-offs of using an extremely low regularization strength (\( C = **1.93*10^3** \)) while demonstrating that the model performs well with the dataset’s complexity.

# %% [markdown]
# ### max_iter case

# %%
# Define the range of values for the 'max_iter' parameter
param_range = np.arange(1, 25, 1)  # Test max_iter values from 1 to 25 in steps of 1

# Create a Logistic Regression classifier
classifier = LogisticRegression(C=C_best_param, solver='liblinear')  # Set a reasonable C value for this test

# Calculate validation scores for different values of max_iter
train_scores, test_scores = validation_curve(
    estimator=classifier,
    X=x_train,
    y=y_train,
    param_name='max_iter',
    param_range=param_range,
    cv=5  # Number of cross-validation folds
)

# Calculate the mean and standard deviation of training and test scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Find the position where the cross-validation score is highest
best_index = np.argmax(test_mean)

# Find the max_iter value corresponding to the found position
max_iter_best_param = param_range[best_index]

# Calculate the indices of points adjacent to the best point
left_index = max(0, best_index - 1)
right_index = min(len(param_range) - 1, best_index + 1)

# Plot the validation curve
plt.plot(param_range, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(param_range, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(param_range, test_mean, color='green', linestyle='--', marker='s', markersize=5, label='Cross-Validation Score')
plt.fill_between(param_range, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')

# Plot markers at points corresponding to the best, left, and right positions
plt.scatter([param_range[best_index], param_range[left_index], param_range[right_index]],
            [test_mean[best_index], test_mean[left_index], test_mean[right_index]],
            color='red', marker='o', s=150, label='Best Position')

# Update plot settings
plt.title('Validation Curve for Logistic Regression (max_iter)')
plt.xlabel('max_iter')
plt.ylabel('Score')
plt.legend(loc='lower right')
plt.grid()
plt.xticks(param_range, rotation=45)

# Show the plot
plt.show()

print(f"The best max_iter value is: {max_iter_best_param}")
# Out:
# The best max_iter value is: 19

# %% [markdown]
# ### Conclusion: Impact of Increasing `max_iter` in Logistic Regression
#
# The hyperparameter `max_iter` controls the maximum number of iterations the optimization algorithm can run before stopping. Its tuning revealed the following key insights:
#
# ---
#
# #### **Pros of Increasing `max_iter`**
# 1. **Improved Convergence**:
#    - Higher `max_iter` allows the optimization process to run longer, ensuring the model can converge even for complex datasets or challenging configurations.
#
# 2. **Better Performance**:
#    - In some cases, increasing `max_iter` can lead to higher accuracy and better cross-validation scores, as the optimization algorithm has more time to find the optimal parameters.
#
# 3. **Flexibility**:
#    - Provides flexibility when working with large datasets or poorly scaled features that require more iterations to converge.
#
# ---
#
# #### **Cons of Increasing `max_iter`**
# 1. **Longer Training Time**:
#    - A higher `max_iter` increases computation time, especially if the dataset is large or the convergence speed is slow.
#
# 2. **Diminishing Returns**:
#    - Beyond a certain point, increasing `max_iter` offers minimal improvement in performance but significantly increases computational cost.
#
# 3. **Risk of Overfitting**:
#    - Allowing excessive iterations without regularization may lead to overfitting the training data.
#
# ---
#
# #### **Optimal Strategy**
# - **Start Small**: Use a moderate default (e.g., `9`) and only increase `max_iter` if convergence warnings are encountered or the model underperforms.
# - **Balance Cost and Benefit**: Select a `max_iter` value that achieves convergence without excessively increasing computational time.
# - **Monitor Performance**: Use cross-validation to confirm that increasing `max_iter` improves generalization rather than just fitting the training data better.
#
# ---
#
# In this experiment, the optimal `max_iter` was found to balance convergence and computational efficiency effectively, ensuring robust model performance.

# %%
lgr = LogisticRegression(random_state=64, max_iter=max_iter_best_param, C = C_best_param)

# Plot the training result for a single model
fig, ax = plt.subplots(figsize=(6, 4))  # Create a single plot with a specified size

# Choose the model and its name
score, report = training(lgr, "Logistic Regression", ax)  # Train and plot the chosen model

# Store the results
scores = [score]
reports = {"Logistic Regression": report}

# Update layout and display the plot
plt.tight_layout()
plt.show()
